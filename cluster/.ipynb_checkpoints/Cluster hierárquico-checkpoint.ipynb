# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.spatial import distance_matrix 
from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import fcluster
import scipy.spatial.distance as ssd
import os
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram
from matplotlib import pylab
# %matplotlib inline

# %% [markdown]
# ### ir para a pasta de dados

# %%
cd C:/Users/eduardo.zanutti/OneDrive - Apsen Farmaceutica S A/Documentos/MBA DataScience/aula_5_analise_cluster/Nao_Supervisionado_USP/dados/
# Out:
# C:\Users\eduardo.zanutti\OneDrive - Apsen Farmaceutica S A\Documentos\MBA DataScience\aula_5_analise_cluster\Nao_Supervisionado_USP\dados

# %% [markdown]
# ###  Verificar arquivos

# %%
ls
# Out:
#  O volume na unidade C ‚ OS
#  O N£mero de S‚rie do Volume ‚ B250-E116
#
#  Pasta de C:\Users\eduardo.zanutti\OneDrive - Apsen Farmaceutica S A\Documentos\MBA DataScience\aula_5_analise_cluster\Nao_Supervisionado_USP\dados
#
# 14/07/2021  16:10    <DIR>          .
# 14/07/2021  16:10    <DIR>          ..
# 03/02/2020  16:58                73 alunos_pap.csv
# 14/07/2021  16:09            17.774 cars_clus.csv
# 03/02/2020  14:53             1.503 MCDONALDS.csv
# 03/02/2020  14:53            39.475 municipios.csv
# 03/11/2020  11:49            13.810 notas_categ.xlsx
#                5 arquivo(s)         72.635 bytes
#                2 pasta(s)   64.292.552.704 bytes dispon¡veis

# %% [markdown]
#  ### Criar caminho da pasta e arquivo

# %%
mc_file = 'MCDONALDS.csv'
cluster_folder = 'C:/Users/eduardo.zanutti/OneDrive - Apsen Farmaceutica S A/Documentos/MBA DataScience/aula_5_analise_cluster/Nao_Supervisionado_USP/dados/'
mc_path=os.path.join(cluster_folder,mc_file)

# %%
print(mc_path)
# Out:
# C:/Users/eduardo.zanutti/OneDrive - Apsen Farmaceutica S A/Documentos/MBA DataScience/aula_5_analise_cluster/Nao_Supervisionado_USP/dados/MCDONALDS.csv

# %% [markdown]
# ### Importar dataset

# %%
df_mc=pd.read_csv(mc_path,sep=';',decimal=',')

# %%
df_mc.head()
# Out:
#            Lanche  Valor Energetico  Carboidratos  Proteinas  Gorduras Totais  \
# 0         Big Mac               504            41         25             27.0
# 1       Big Tasty               843            45         41             55.0
# 2       Quarterao               558            36         31             32.0
# 3  Mcnifico Bacon               625            38         34             37.0
# 4  Cheddar McMelt               507            33         29             29.0
#
#    Gorduras Saturadas  Gorduras Trans   Colesterol  Fibra Alimentar  Sodio  \
# 0                12.0              0.5          54              3.5    960
# 1                24.0              1.7         104              5.1   1511
# 2                16.0              1.3          86              3.6   1216
# 3                16.0              1.3          95              3.9   1255
# 4                14.0              1.2          81              2.9    819
#
#    Calcio  Ferro
# 0     162    6.5
# 1     381    8.2
# 2     275   10.0
# 3     209   11.0
# 4     199   10.0

# %%
df_mc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Lanche              25 non-null     object
#  1   Valor Energetico    25 non-null     int64
#  2   Carboidratos        25 non-null     int64
#  3   Proteinas           25 non-null     int64
#  4   Gorduras Totais     25 non-null     float64
#  5   Gorduras Saturadas  25 non-null     float64
#  6   Gorduras Trans      25 non-null     float64
#  7   Colesterol          25 non-null     int64
#  8   Fibra Alimentar     25 non-null     float64
#  9   Sodio               25 non-null     int64
#  10  Calcio              25 non-null     int64
#  11  Ferro               25 non-null     float64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 2.5+ KB

# %% [markdown]
# ### Padronizar os Dados

# %%
df_mc.index=df_mc.iloc[:,0]

# %%
df_mc=df_mc.iloc[:,1:]

# %%
x = df_mc.values #Extrair array do DataFrame
x = np.nan_to_num(x) #substituir nulos por 0
#df_standardized_manual = (df_mc - df_mc.mean()) / df_mc.std(ddof=1)
x_std = StandardScaler().fit_transform(x) #Array Pdronizado
df_std=pd.DataFrame(x_std) #Voltar para o DataFrame com os dados padronizados
df_std.columns=df_mc.columns
df_std.index=df_mc.index
df_std
# Out:
#                         Valor Energetico  Carboidratos  Proteinas  \
# Lanche
# Big Mac                         0.061012     -0.039432  -0.226198
# Big Tasty                       2.080827      0.398701   1.187539
# Quarterao                       0.382752     -0.587098   0.303953
# Mcnifico Bacon                  0.781949     -0.368032   0.569029
# Cheddar McMelt                  0.078886     -0.915698   0.127236
# McFish                         -0.719507     -0.368032  -0.844708
# McChicken                      -0.236896     -0.148965  -0.844708
# McChicken Jr                   -0.934001     -0.915698  -1.286500
# Chicken Classic Crispy         -0.022403      1.165434  -0.314556
# Chicken Classic Grill          -0.409683      0.289168   0.569029
# Chicken Club Crispy             0.692576      1.384501   0.303953
# Chicken Club Grill              0.305296      0.508234   1.187539
# Chicken Lemon Crispy           -0.236896      1.384501  -0.314556
# Chicken Lemon Grill            -0.624177      0.508234   0.569029
# Cheeseburger                   -1.094871     -1.025232  -1.109783
# Hamburger                      -1.410653     -1.134765  -1.286500
# Wrap Grill Maionese            -0.916126     -1.353832  -0.756349
# Wrap Crispy Maionese           -0.725465     -0.915698  -1.198142
# Wrap Grill Lemon               -1.118704     -1.244298  -0.756349
# Wrap Crispy Lemon              -0.928043     -0.806165  -1.198142
# Chicken Bacon Crispy            0.126551      0.398701  -0.049481
# Chicken Bacon Grill            -0.409683     -1.134765   1.010822
# Angus Bacon                     2.188074      1.713101   2.336200
# Angus Deluxe                    2.199990      1.603567   2.071124
# CBO                             0.889195      1.603567  -0.049481
#
#                         Gorduras Totais  Gorduras Saturadas  Gorduras Trans   \
# Lanche
# Big Mac                        0.231040            0.495453        -0.181818
# Big Tasty                      2.512109            2.384093         2.090909
# Quarterao                      0.638373            1.125000         1.333333
# Mcnifico Bacon                 1.045707            1.125000         1.333333
# Cheddar McMelt                 0.393973            0.810227         1.143939
# McFish                        -0.665095           -0.480344        -0.371212
# McChicken                      0.068106           -0.448867        -0.560606
# McChicken Jr                  -0.583628           -0.684947        -0.371212
# Chicken Classic Crispy        -0.339228           -0.700685        -0.750000
# Chicken Club Crispy    -0.452094
# Chicken Club Grill     -0.452094
# Chicken Lemon Crispy   -0.627108
# Chicken Lemon Grill    -0.627108
# Cheeseburger           -0.032062
# Hamburger              -0.032062
# Wrap Grill Maionese    -1.211652
# Wrap Crispy Maionese   -1.218653
# Wrap Grill Lemon       -1.229154
# Wrap Crispy Lemon      -1.232654
# Chicken Bacon Crispy    0.037943
# Chicken Bacon Grill    -0.137070
# Angus Bacon            -0.102068
# Angus Deluxe           -0.172073
# CBO                     0.913010

# %% [markdown]
# ###  Criar matriz de distâncias

# %%
dist_matrix = distance_matrix(x_std,x_std)

# %%
dist_matrix = distance_matrix(df_std,df_std) #Criar Matriz de distâncias
df_dist_matrix=pd.DataFrame(dist_matrix) #Transformar em DataFrame a Matriz de Distâncias
df_dist_matrix.index=df_mc.index
df_dist_matrix.columns=df_mc.index
df_dist_matrix
# Out:
# Lanche                   Big Mac  Big Tasty  Quarterao  Mcnifico Bacon  \
# Lanche
# Big Mac                 0.000000   5.774519   2.897350        3.094498
# Big Tasty               5.774519   0.000000   3.764287        3.686882
# Quarterao               2.897350   3.764287   0.000000        1.162640
# Mcnifico Bacon          3.094498   3.686882   1.162640        0.000000
# Cheddar McMelt          2.318238   5.111455   1.659712        1.921445
# McFish                  2.177795   7.522566   4.472379        4.933418
# McChicken               1.969343   7.328849   4.560811        4.635305
# McChicken Jr            3.234387   8.702987   5.706616        5.978199
# Chicken Classic Crispy  3.608421   7.774952   5.798998        5.719459
# Chicken Classic Grill   3.302315   7.939791   5.474270        5.459528
# Chicken Club Crispy     3.780072   6.006068   4.930347        4.746069
# Chicken Club Grill      3.200362   6.129856   4.399572        4.283990
# Chicken Lemon Crispy    3.628850   7.893907   5.872992        5.832198
# Chicken Lemon Grill     3.589015   8.313070   5.788889        5.816054
# Cheeseburger            2.668080   8.026103   4.809295        5.292811
# Hamburger               3.649980   9.209524   5.930663        6.283975
# Wrap Grill Maionese     3.478958   8.384685   5.520068        6.030721
# Wrap Crispy Maionese    3.169008   8.061700   5.344250        5.836937
# Wrap Grill Lemon        3.737345   8.724944   5.797394        6.325840
# Wrap Crispy Lemon       3.419366   8.446087   5.660298        6.167032
# Chicken Bacon Crispy    1.802639   5.954133   3.601210        3.795144
# Chicken Bacon Grill     2.627490   6.808232   3.970892        4.248232
# Angus Bacon             6.285993   3.763362   5.297623        4.811697
# Angus Deluxe            5.940909   3.418213   4.996225        4.513767
# CBO                     2.395311   4.503733   2.967406        2.980269
#
# Lanche                  Cheddar McMelt    McFish  McChicken  McChicken Jr  \
# Lanche
# Big Mac                       2.318238  2.177795   1.969343      3.234387
# Big Tasty                     5.111455  7.522566   7.328849      8.702987
# Quarterao                     1.659712  4.472379   4.560811      5.706616
# Mcnifico Bacon                1.921445  4.933418   4.635305      5.978199
# Cheddar McMelt                0.000000  3.633952   3.833500      4.671404
# McFish                        3.633952  0.000000   1.853684      1.985953
# McChicken                     3.833500  1.853684   0.000000      2.145449
# Chicken Bacon Grill                 2.630575             0.000000
# Angus Bacon                         5.881283             6.658749
# Angus Deluxe                        5.668715             6.461698
# CBO                                 2.444256             4.048932
#
# Lanche                  Angus Bacon  Angus Deluxe      CBO
# Lanche
# Big Mac                    6.285993      5.940909  2.395311
# Big Tasty                  3.763362      3.418213  4.503733
# Quarterao                  5.297623      4.996225  2.967406
# Mcnifico Bacon             4.811697      4.513767  2.980269
# Cheddar McMelt             6.253470      5.894813  3.398297
# McFish                     7.899624      7.576190  3.965412
# McChicken                  7.213114      6.916137  3.626321
# McChicken Jr               8.944105      8.598952  5.222998
# Chicken Classic Crispy     7.030858      6.836160  4.105938
# Chicken Classic Grill      7.135149      6.945743  4.375351
# Chicken Club Crispy        5.012033      4.904170  3.209804
# Chicken Club Grill         5.041992      4.937619  3.288592
# Chicken Lemon Crispy       7.170258      6.975041  4.201319
# Chicken Lemon Grill        7.510084      7.326384  4.648303
# Cheeseburger               8.512519      8.198445  4.703308
# Hamburger                  9.504773      9.187782  5.722694
# Wrap Grill Maionese        8.649055      8.356863  5.192096
# Wrap Crispy Maionese       8.369673      8.066655  4.748009
# Wrap Grill Lemon           8.961273      8.677211  5.436223
# Wrap Crispy Lemon          8.722619      8.430053  5.002737
# Chicken Bacon Crispy       5.881283      5.668715  2.444256
# Chicken Bacon Grill        6.658749      6.461698  4.048932
# Angus Bacon                0.000000      0.705961  4.929023
# Angus Deluxe               0.705961      0.000000  4.594948
# CBO                        4.929023      4.594948  0.000000
#
# [25 rows x 25 columns]

# %% [markdown]
# ### Condensar a matriz de distâncias

# %%
import scipy.spatial.distance as ssd
# convert the redundant n*n square matrix form into a condensed nC2 array
distArray = ssd.squareform(dist_matrix)

# %% [markdown]
# ### Clusterizar

# %%
z = hierarchy.linkage(distArray,method = 'single',metric='euclidean')

# %%
#agglom = AgglomerativeClustering(n_clusters = 4, linkage = "single")
#agglom.fit(x_std)
#df_mc['sklearn.cluster']=agglom.labels_

# %% [markdown]
# ### Dendograma

# %%
threshold = 2.8 #Defina o valor de threshold para a formação de grupos
dendro = hierarchy.dendrogram(z,  labels=df_mc.index, color_threshold=threshold,leaf_rotation=90, leaf_font_size=12, orientation = 'top')
fig = plt.gcf()
fig.set_size_inches(20, 20)
titulo=plt.title('Dendograma MC Donalds')
plt.grid(axis='y')
plt.axhline(linestyle='--', y=threshold)

# %% [markdown]
# ### Criação dos clusters

# %%
k = 4 #escolha o número de grupos
clusters = fcluster(z, k, criterion='maxclust')
df_mc['cluster']=clusters

# %%
df_mc
# Out:
#                         Valor Energetico  Carboidratos  Proteinas  \
# Lanche
# Big Mac                              504            41         25
# Big Tasty                            843            45         41
# Quarterao                            558            36         31
# Mcnifico Bacon                       625            38         34
# Cheddar McMelt                       507            33         29
# McFish                               373            38         18
# McChicken                            454            40         18
# McChicken Jr                         337            33         13
# Chicken Classic Crispy               490            52         24
# Chicken Classic Grill                425            44         34
# Chicken Club Crispy                  610            54         31
# Chicken Club Grill                   545            46         41
# Chicken Lemon Crispy                 454            54         24
# Chicken Lemon Grill                  389            46         34
# Cheeseburger                         310            32         15
# Hamburger                            257            31         13
# Wrap Grill Maionese                  340            29         19
# Wrap Crispy Maionese                 372            33         14
# Wrap Grill Lemon                     306            30         19
# Wrap Crispy Lemon                    338            34         14
# Chicken Bacon Crispy                 515            45         27
# Chicken Bacon Grill                  425            31         39
# Angus Bacon                          861            57         54
# Angus Deluxe                         863            56         51
# CBO                                  643            56         27
#
#                         Gorduras Totais  Gorduras Saturadas  Gorduras Trans   \
# Lanche
# Big Mac                            27.0                12.0              0.5
# Big Tasty                          55.0                24.0              1.7
# Quarterao                          32.0                16.0              1.3
# Mcnifico Bacon                     37.0                16.0              1.3
# Cheddar McMelt                     29.0                14.0              1.2
# McFish                             16.0                 5.8              0.4
# McChicken                          25.0                 6.0              0.3
# McChicken Jr                       17.0                 4.5              0.4
# Chicken Classic Crispy             20.0                 4.4              0.2
# Chicken Classic Grill              12.0                 2.0              0.2
# Chicken Club Crispy                30.0                 9.3              0.5
# Chicken Club Grill                 22.0                 7.0              0.4
# Chicken Lemon Crispy               16.0                 7.0              0.2
# Chicken Lemon Grill                 7.8                 0.8              0.2
# Cheeseburger                       14.0                 7.0              0.4
# Hamburger                           9.3                 4.1              0.3
# Wrap Grill Maionese                16.0                 3.4              0.1
# Wrap Crispy Maionese               20.0                 4.6              0.2
# Wrap Grill Lemon                   12.0                 2.1              0.1
# Wrap Crispy Lemon                  16.0                 3.3              0.1
# Chicken Bacon Crispy               25.0                10.0              0.4
# Chicken Bacon Grill                16.0                 5.0              0.4
# Angus Bacon                        46.0                21.0              1.7
# Angus Deluxe                       49.0                21.0              1.7
# CBO                                35.0                11.0              0.7
#
#                         Colesterol  Fibra Alimentar  Sodio  Calcio  Ferro  \
# Lanche
# Big Mac                         54              3.5    960     162   6.50
# Big Tasty                      104              5.1   1511     381   8.20
# Quarterao                       86              3.6   1216     275  10.00
# Mcnifico Bacon                  95              3.9   1255     209  11.00
# Cheddar McMelt                  81              2.9    819     199  10.00
# McFish                          43              2.2    773     168   3.80
# McChicken                       49              3.1   1068      67   4.00
# McChicken Jr                    11              3.3    633      58   3.10
# Chicken Classic Crispy          33              6.7   1361      38   2.50
# Chicken Classic Grill           68              5.5   1072      44   2.60
# Chicken Club Crispy             58              6.7   1831     115   3.00
# Chicken Club Grill              93              5.5   1542     121   3.00
# Chicken Lemon Crispy            28              6.7   1290      37   2.50
# Chicken Lemon Grill             63              5.5   1001      43   2.50
# Cheeseburger                    31              1.9    781     146   4.20
# Hamburger                       22              1.9    542      70   4.20
# Wrap Grill Maionese             42              1.2    888     175   0.83
# Wrap Crispy Maionese            25              1.8   1032     172   0.81
# Wrap Grill Lemon                38              1.1    829     175   0.78
# Wrap Crispy Lemon               21              1.8    974     172   0.77
# Chicken Bacon Crispy            47              3.0   1487     165   4.40
# Chicken Bacon Grill             83              3.0   1151     161   3.90
# Angus Bacon                    145              5.0   1917     193   4.00
# Angus Deluxe                   139              5.0   1716     197   3.80
# CBO                             71              4.0   1220     236   6.90
#
#                         cluster
# Lanche
# Big Mac                       1
# Big Tasty                     4
# Quarterao                     1
# Mcnifico Bacon                1
# Cheddar McMelt                1
# McFish                        1
# McChicken                     1
# McChicken Jr                  1
# Chicken Classic Crispy        1
# Chicken Classic Grill         1
# Chicken Club Crispy           1
# Chicken Club Grill            1
# Chicken Lemon Crispy          1
# Chicken Lemon Grill           1
# Cheeseburger                  1
# Hamburger                     1
# Wrap Grill Maionese           1
# Wrap Crispy Maionese          1
# Wrap Grill Lemon              1
# Wrap Crispy Lemon             1
# Chicken Bacon Crispy          1
# Chicken Bacon Grill           2
# Angus Bacon                   3
# Angus Deluxe                  3
# CBO                           1

# %% [markdown]
# ###  Analíse média de macronutrientes por cluster

# %%
df_mc.groupby(['cluster']).mean()
# Out:
#          Valor Energetico  Carboidratos  Proteinas  Gorduras Totais  \
# cluster
# 1              445.333333     40.238095       24.0        20.861905
# 2              425.000000     31.000000       39.0        16.000000
# 3              862.000000     56.500000       52.5        47.500000
# 4              843.000000     45.000000       41.0        55.000000
#
#          Gorduras Saturadas  Gorduras Trans   Colesterol  Fibra Alimentar  \
# cluster
# 1                  7.157143         0.447619   50.428571         3.609524
# 2                  5.000000         0.400000   83.000000         3.000000
# 3                 21.000000         1.700000  142.000000         5.000000
# 4                 24.000000         1.700000  104.000000         5.100000
#
#                Sodio      Calcio     Ferro
# cluster
# 1        1074.952381  135.571429  4.161429
# 2        1151.000000  161.000000  3.900000
# 3        1816.500000  195.000000  3.900000
# 4        1511.000000  381.000000  8.200000

# %% [markdown]
# ###  Cluster 1

# %% [markdown]
# ##### Lanches Tradicionais

# %%
df_mc[df_mc['cluster']==1].sort_values(['Valor Energetico'])
# Out:
#                         Valor Energetico  Carboidratos  Proteinas  \
# Lanche
# Hamburger                            257            31         13
# Wrap Grill Lemon                     306            30         19
# Cheeseburger                         310            32         15
# McChicken Jr                         337            33         13
# Wrap Crispy Lemon                    338            34         14
# Wrap Grill Maionese                  340            29         19
# Wrap Crispy Maionese                 372            33         14
# McFish                               373            38         18
# Chicken Lemon Grill                  389            46         34
# Chicken Classic Grill                425            44         34
# McChicken                            454            40         18
# Chicken Lemon Crispy                 454            54         24
# Chicken Classic Crispy               490            52         24
# Big Mac                              504            41         25
# Cheddar McMelt                       507            33         29
# Chicken Bacon Crispy                 515            45         27
# Chicken Club Grill                   545            46         41
# Quarterao                            558            36         31
# Chicken Club Crispy                  610            54         31
# Mcnifico Bacon                       625            38         34
# CBO                                  643            56         27
#
#                         Gorduras Totais  Gorduras Saturadas  Gorduras Trans   \
# Lanche
# Hamburger                           9.3                 4.1              0.3
# Wrap Grill Lemon                   12.0                 2.1              0.1
# Cheeseburger                       14.0                 7.0              0.4
# McChicken Jr                       17.0                 4.5              0.4
# Wrap Crispy Lemon                  16.0                 3.3              0.1
# Wrap Grill Maionese                16.0                 3.4              0.1
# Wrap Crispy Maionese               20.0                 4.6              0.2
# McFish                             16.0                 5.8              0.4
# Chicken Lemon Grill                 7.8                 0.8              0.2
# Chicken Classic Grill              12.0                 2.0              0.2
# McChicken                          25.0                 6.0              0.3
# Chicken Lemon Crispy               16.0                 7.0              0.2
# Chicken Classic Crispy             20.0                 4.4              0.2
# Big Mac                            27.0                12.0              0.5
# Cheddar McMelt                     29.0                14.0              1.2
# Chicken Bacon Crispy               25.0                10.0              0.4
# Chicken Club Grill                 22.0                 7.0              0.4
# Quarterao                          32.0                16.0              1.3
# Chicken Club Crispy                30.0                 9.3              0.5
# Mcnifico Bacon                     37.0                16.0              1.3
# CBO                                35.0                11.0              0.7
#
#                         Colesterol  Fibra Alimentar  Sodio  Calcio  Ferro  \
# Lanche
# Hamburger                       22              1.9    542      70   4.20
# Wrap Grill Lemon                38              1.1    829     175   0.78
# Cheeseburger                    31              1.9    781     146   4.20
# McChicken Jr                    11              3.3    633      58   3.10
# Wrap Crispy Lemon               21              1.8    974     172   0.77
# Wrap Grill Maionese             42              1.2    888     175   0.83
# Wrap Crispy Maionese            25              1.8   1032     172   0.81
# McFish                          43              2.2    773     168   3.80
# Chicken Lemon Grill             63              5.5   1001      43   2.50
# Chicken Classic Grill           68              5.5   1072      44   2.60
# McChicken                       49              3.1   1068      67   4.00
# Chicken Lemon Crispy            28              6.7   1290      37   2.50
# Chicken Classic Crispy          33              6.7   1361      38   2.50
# Big Mac                         54              3.5    960     162   6.50
# Cheddar McMelt                  81              2.9    819     199  10.00
# Chicken Bacon Crispy            47              3.0   1487     165   4.40
# Chicken Club Grill              93              5.5   1542     121   3.00
# Quarterao                       86              3.6   1216     275  10.00
# Chicken Club Crispy             58              6.7   1831     115   3.00
# Mcnifico Bacon                  95              3.9   1255     209  11.00
# CBO                             71              4.0   1220     236   6.90
#
#                         cluster
# Lanche
# Hamburger                     1
# Wrap Grill Lemon              1
# Cheeseburger                  1
# McChicken Jr                  1
# Wrap Crispy Lemon             1
# Wrap Grill Maionese           1
# Wrap Crispy Maionese          1
# McFish                        1
# Chicken Lemon Grill           1
# Chicken Classic Grill         1
# McChicken                     1
# Chicken Lemon Crispy          1
# Chicken Classic Crispy        1
# Big Mac                       1
# Cheddar McMelt                1
# Chicken Bacon Crispy          1
# Chicken Club Grill            1
# Quarterao                     1
# Chicken Club Crispy           1
# Mcnifico Bacon                1
# CBO                           1

# %% [markdown]
# ###  Cluster 2

# %% [markdown]
# ##### Proteico e com baixo teor de gordura

# %%
df_mc[df_mc['cluster']==2].sort_values(['Valor Energetico'])
# Out:
#                      Valor Energetico  Carboidratos  Proteinas  \
# Lanche
# Chicken Bacon Grill               425            31         39
#
#                      Gorduras Totais  Gorduras Saturadas  Gorduras Trans   \
# Lanche
# Chicken Bacon Grill             16.0                 5.0              0.4
#
#                      Colesterol  Fibra Alimentar  Sodio  Calcio  Ferro  \
# Lanche
# Chicken Bacon Grill          83              3.0   1151     161    3.9
#
#                      cluster
# Lanche
# Chicken Bacon Grill        2

# %% [markdown]
# ###  Cluster 3

# %% [markdown]
# ##### Top Calóricos

# %%
df_mc[df_mc['cluster']==3].sort_values(['Valor Energetico'])
# Out:
#               Valor Energetico  Carboidratos  Proteinas  Gorduras Totais  \
# Lanche
# Angus Bacon                861            57         54             46.0
# Angus Deluxe               863            56         51             49.0
#
#               Gorduras Saturadas  Gorduras Trans   Colesterol  \
# Lanche
# Angus Bacon                 21.0              1.7         145
# Angus Deluxe                21.0              1.7         139
#
#               Fibra Alimentar  Sodio  Calcio  Ferro  cluster
# Lanche
# Angus Bacon               5.0   1917     193    4.0        3
# Angus Deluxe              5.0   1716     197    3.8        3

# %% [markdown]
# ###  Cluster 4

# %% [markdown]
# ##### Mais gorduroso

# %%
df_mc[df_mc['cluster']==4].sort_values(['Valor Energetico'])
# Out:
#            Valor Energetico  Carboidratos  Proteinas  Gorduras Totais  \
# Lanche
# Big Tasty               843            45         41             55.0
#
#            Gorduras Saturadas  Gorduras Trans   Colesterol  Fibra Alimentar  \
# Lanche
# Big Tasty                24.0              1.7         104              5.1
#
#            Sodio  Calcio  Ferro  cluster
# Lanche
# Big Tasty   1511     381    8.2        4

# %% [markdown]
# ### Criar labels para os clusters

# %%
nome_clusters=[[1,'Lanches Tradicionais'],
               [2,'Proteico e com baixo teor de gordura'],
               [3,'Top Calóricos'],
               [4,'Mais gorduroso']]

# %%
df_nome_clusters=pd.DataFrame(np.array(nome_clusters),columns=['cluster','cluster_name'])

# %%
df_nome_clusters
# Out:
#   cluster                          cluster_name
# 0       1                  Lanches Tradicionais
# 1       2  Proteico e com baixo teor de gordura
# 2       3                         Top Calóricos
# 3       4                        Mais gorduroso

# %%
df_nome_clusters['cluster']=df_nome_clusters['cluster'].astype(int)

# %% [markdown]
# ### Merge com o DataFrame principal

# %%
df_mc_clus_nm=pd.merge(df_mc,df_nome_clusters,how='left',on=['cluster'])

# %%
df_mc_clus_nm.index=df_mc.index

# %%
df_mc=df_mc_clus_nm

# %% [markdown]
# ### Fução para os labels com os clusters no dendograma

# %%
def llf(id):
    return '%s - %s - cluster [%s]' % (df_mc['cluster_name'][id],df_mc.index[id],int(float(df_mc['cluster'][id])))

# %%
#vertical
#dendro = hierarchy.dendrogram(z,  leaf_label_func=llf, color_threshold=threshold,leaf_rotation=0, leaf_font_size=12, orientation = 'right')
#fig = plt.gcf()
#fig.set_size_inches(20, 15)
#titulo=plt.title('Dendograma MC Donalds')
#plt.grid(axis='x')
#plt.axvline(linestyle='--', x=threshold)

# %%
#horizontal
dendro = hierarchy.dendrogram(z,  leaf_label_func=llf, color_threshold=threshold,leaf_rotation=90, leaf_font_size=12, orientation = 'top')
fig = plt.gcf()
fig.set_size_inches(20, 10)
titulo=plt.title('Dendograma MC Donalds')
plt.grid(axis='y')
plt.axhline(linestyle='--', y=threshold)
